# %%
import tkinter as tk
from tkinter import Scrollbar, messagebox

def check_answer():
    ans1 = answer1_input.get()
    ans2 = answer2_input.get()
    ans3 = answer3_input.get()
    ans4 = answer4_input.get()
    ans5 = answer5_input.get()
    ans6 = answer6_input.get()
    ans7 = answer7_input.get()
    ans8 = answer8_input.get()
    ans9 = answer9_input.get()
    ans10 = answer10_input.get()
    correct_ans1 = "m"
    correct_ans2 = "t"
    correct_ans3 = "v"
    correct_ans4 = "g"
    correct_ans5 = "f"
    correct_ans6 = "I"
    correct_ans7 = "P"
    correct_ans8 = "m"
    correct_ans9 = "R"
    correct_ans10 = "d"

    if ans1.lower() == correct_ans1.lower():
        messagebox.showinfo("Correct!", "Your answer is correct!")
    else:
        messagebox.showerror("Incorrect!", "Sorry, that's not the correct answer.")

    if ans2.lower() == correct_ans2.lower():
        messagebox.showinfo("Correct!", "Your answer is correct!")
    else:
        messagebox.showerror("Incorrect!", "Sorry, that's not the correct answer.")

    if ans3.lower() == correct_ans3.lower():
        messagebox.showinfo("Correct!", "Your answer is correct!")
    else:
        messagebox.showerror("Incorrect!", "Sorry, that's not the correct answer.")

# Create the main window with a specified size
window = tk.Tk()
window.title("Intelligence Test")
window.geometry("800x600")

# Create question and answer entry fields
tk.Label(window, text="F=_a").pack(pady=10)
answer1_input = tk.Entry(window)
answer1_input.pack(pady=5)

tk.Label(window, text="S=v_").pack(pady=10)
answer2_input = tk.Entry(window)
answer2_input.pack(pady=5)

tk.Label(window, text="E=(1/2)m_^2").pack(pady=10)
answer3_input = tk.Entry(window)
answer3_input.pack(pady=5)

tk.Label(window, text="E=m_h").pack(pady=10)
answer4_input = tk.Entry(window)
answer4_input.pack(pady=5)

tk.Label(window, text="v=_λ").pack(pady=10)
answer5_input = tk.Entry(window)
answer5_input.pack(pady=5)

tk.Label(window, text="Q=_t").pack(pady=10)
answer6_input = tk.Entry(window)
answer6_input.pack(pady=5)

tk.Label(window, text="_=IV").pack(pady=10)
answer7_input = tk.Entry(window)
answer7_input.pack(pady=5)

tk.Label(window, text="ρ=_/V").pack(pady=10)
answer8_input = tk.Entry(window)
answer8_input.pack(pady=5)

tk.Label(window, text="P=((I)^2)_").pack(pady=10)
answer9_input = tk.Entry(window)
answer9_input.pack(pady=5)

tk.Label(window, text="M=F_").pack(pady=10)
answer10_input = tk.Entry(window)
answer10_input.pack(pady=5)

# Create a submit button
tk.Button(window, text="Submit", command=check_answer).pack(pady=20)

# Run the application
window.mainloop()
